# %%
import requests
import numpy as np
from bs4 import BeautifulSoup
import pandas as pd
import time
from typing import List, Dict, Optional

# %%
class TikiAPIScraper:
    def __init__(self, base_url: str, query: str, max_pages: Optional[int] = None, limit_per_page: Optional[int] = 24):
        self.base_url = base_url
        self.query = query
        self.max_pages = max_pages
        self.limit_per_page = limit_per_page
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'
        }
        self.products_data = []

    def fetch_data(self, page: int):
        """Fetch product data from Tiki API."""
        api_url = f"{self.base_url}?limit={self.limit_per_page}&q={self.query}&page={page}"
        try:
            response = requests.get(api_url, headers=self.headers)
            response.raise_for_status()
            data = response.json()
            return data
        except requests.RequestException as e:
            print(f"Error fetching page {page}: {e}")
            return None

    def get_total_pages(self):
        """Get the total number of pages from the API."""
        data = self.fetch_data(1)
        if data and "paging" in data:
            total_products = data["paging"].get("total", 0)
            products_per_page = data["paging"].get("per_page", 24)
            total_pages = (total_products // products_per_page) + (total_products % products_per_page > 0)
            print(f"Total pages available: {total_pages}")
            return total_pages
        return 1

    def scrape(self):
        """Scrape product data across pages."""
        if self.max_pages is None:
            self.max_pages = self.get_total_pages()

        page = 1
        while page <= self.max_pages:
            # In ra link của từng trang mà scraper truy cập
            api_url = f"{self.base_url}?limit=24&q={self.query}&page={page}"
            print(f"Fetching URL: {api_url}")

            response_data = self.fetch_data(page)

            if not response_data or "data" not in response_data:
                print(f"No more products found on page {page}. Stopping scrape.")
                break

            products = response_data["data"]
            for product in products:
                quantity_sold = product.get("quantity_sold", {}).get("value", 0)
                product_info = {
                    "Tên sản phẩm": product.get("name", "N/A"),
                    "Tên cửa hàng": product.get("seller_name", "N/A"),
                    "Giá": product.get("price", "N/A"),
                    "Thương hiệu": product.get("brand_name", "N/A"),
                    "Lượt đánh giá": product.get("review_count", "N/A"),
                    "Điểm đánh giá trung bình": product.get("rating_average","N/A"),
                    "Số lượng đã bán": quantity_sold,
                    "Link": f"https://tiki.vn/{product.get('url_path', '')}"
                }
                self.products_data.append(product_info)

            # Delay 2s before fetching the next page
            page += 1
            time.sleep(2)

        print(f"Total products scraped: {len(self.products_data)}")

    def save_to_csv(self, filename: str):
        """Save the scraped data to a CSV file."""
        df = pd.DataFrame(self.products_data)
        df.to_csv(filename, sep=',', index=False, encoding='utf-8')
        print(f"Data saved to {filename}")

# %%
if __name__ == "__main__":
    base_url = "https://tiki.vn/api/v2/products"
    limit_per_page = 48
    max_pages = None  # None to scrape all pages, or specify the number of pages to scrape
    
    search_keywords = ["thời trang", "quần", "áo", "váy"]
    brandedStores = []

    for keyword in search_keywords:
        scraper = TikiAPIScraper(base_url, keyword, max_pages, limit_per_page)
        scraper.scrape()
        scraper.save_to_csv(f"./Data/tiki_products_{keyword}.csv")
# Out:
# Total pages available: 50
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=1
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=2
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=3
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=4
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=5
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=6
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=7
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=8
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=9
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=10
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=11
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=12
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=13
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=14
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=15
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=16
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=17
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=18
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=19
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=20
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=21
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=22
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=23
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=24
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=25
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=26
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=27
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=28
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=29
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=30
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=31
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=32
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=33
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=34
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=35
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=36
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=37
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=38
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=39
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=40
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=41
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=42
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=43
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=44
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=45
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=46
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=47
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=48
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=49
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=thời trang&page=50
# Total products scraped: 2000
# Data saved to tiki_products_thời trang.csv
# Total pages available: 50
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=1
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=2
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=3
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=4
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=5
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=6
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=7
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=8
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=9
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=10
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=11
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=12
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=13
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=14
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=15
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=16
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=17
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=18
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=19
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=20
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=21
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=22
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=23
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=24
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=25
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=26
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=27
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=28
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=29
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=30
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=31
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=32
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=33
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=34
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=35
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=36
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=37
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=38
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=39
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=40
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=41
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=42
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=43
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=44
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=45
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=46
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=47
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=48
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=49
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=quần&page=50
# Total products scraped: 2000
# Data saved to tiki_products_quần.csv
# Total pages available: 50
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=1
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=2
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=3
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=4
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=5
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=6
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=7
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=8
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=9
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=10
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=11
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=12
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=13
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=14
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=15
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=16
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=17
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=18
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=19
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=20
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=21
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=22
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=23
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=24
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=25
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=26
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=27
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=28
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=29
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=30
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=31
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=32
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=33
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=34
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=35
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=36
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=37
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=38
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=39
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=40
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=41
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=42
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=43
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=44
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=45
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=46
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=47
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=48
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=49
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=áo&page=50
# Total products scraped: 2000
# Data saved to tiki_products_áo.csv
# Total pages available: 50
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=1
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=2
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=3
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=4
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=5
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=6
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=7
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=8
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=9
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=10
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=11
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=12
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=13
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=14
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=15
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=16
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=17
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=18
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=19
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=20
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=21
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=22
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=23
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=24
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=25
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=26
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=27
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=28
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=29
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=30
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=31
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=32
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=33
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=34
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=35
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=36
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=37
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=38
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=39
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=40
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=41
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=42
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=43
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=44
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=45
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=46
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=47
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=48
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=49
# Fetching URL: https://tiki.vn/api/v2/products?limit=24&q=váy&page=50
# Total products scraped: 2000
# Data saved to tiki_products_váy.csv

# %%
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# import time

# class ShopeeSeleniumScraper:
#     def __init__(self, base_url="https://shopee.vn/mall", delay=5, limit=10):
#         """
#         Initialize the scraper with the base URL, delay between actions, and limit for categories.
#         :param base_url: Shopee Mall URL.
#         :param delay: Time delay (in seconds) to wait for the content to load.
#         :param limit: Maximum number of categories to scrape.
#         """
#         self.base_url = base_url
#         self.delay = delay
#         self.limit = limit
#         self.driver = webdriver.Chrome()  # Initialize Chrome WebDriver

#     def scrape(self):
#         """
#         Scrape categories from Shopee Mall using Selenium.
#         :return: List of categories with names and URLs.
#         """
#         print("Opening Shopee Mall page...")
#         self.driver.get(self.base_url)
#         time.sleep(self.delay)  # Wait for the content to load

#         categories = []
#         try:
#             # Locate the categories in the "Danh mục" section
#             category_elements = self.driver.find_elements(By.CSS_SELECTOR, "ul.image-carousel__item-list li.image-carousel__item a")
#             for i, category in enumerate(category_elements):
#                 if i >= self.limit:  # Stop after reaching the limit
#                     break
#                 name = category.find_element(By.CSS_SELECTOR, "div.gRCeBZ").text.strip()  # Category name
#                 link = category.get_attribute("href")  # Category link
#                 categories.append({"name": name, "href": link})
#         except Exception as e:
#             print(f"Error scraping categories: {e}")
#         finally:
#             self.driver.quit()  # Close the browser

#         return categories

# # Example usage
# if __name__ == "__main__":
#     scraper = ShopeeSeleniumScraper(delay=5, limit=10)  # Adjust delay and limit as needed
#     categories = scraper.scrape()
#     print("Categories:", categories)
